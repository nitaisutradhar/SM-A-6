# %% [markdown]
# <a href="https://colab.research.google.com/github/nitaisutradhar/SM-A-6/blob/main/A_6_Gym_Membership.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required packages (run this first in Google Colab)
# !pip install numpy pandas matplotlib seaborn

# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
import warnings
warnings.filterwarnings('ignore')
# Out:
# Mounted at /content/drive

# %%
gym = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/datasets/gym_membership.csv')

# %% [markdown]
# # Understand the data

# %%
# check data
print(gym.head())
print(gym.shape) # How many rows and colums
print(gym.columns.tolist()) # column names
# Out:
#    id  gender   birthday  Age abonoment_type  visit_per_week  \
# 0   1  Female  4/18/1997   27        Premium               4
# 1   2  Female  9/18/1977   47       Standard               3
# 2   3    Male  3/30/1983   41        Premium               1
# 3   4    Male  4/12/1980   44        Premium               3
# 4   5    Male  9/10/1980   44       Standard               2
#
#         days_per_week  attend_group_lesson            fav_group_lesson  \
# 0  Mon, Sat, Tue, Wed                 True  Kickboxen, BodyPump, Zumba
# 1       Mon, Sat, Wed                False                         NaN
# 2                 Sat                 True                       XCore
# 3       Sat, Tue, Wed                False                         NaN
# 4            Thu, Wed                 True        Running, Yoga, Zumba
#
#   avg_time_check_in avg_time_check_out  avg_time_in_gym  drink_abo  \
# 0          19:31:00           21:27:00              116      False
# ...

# %% [markdown]
# # Task 1: Basic Matplotlib (3 plots)

# %% [markdown]
# ## 1. Bar chart of gym membership types
# Use: gym['abonoment_type'].value_counts()

# %%
plt.figure(figsize = (8,5))
membership_counts = gym['abonoment_type'].value_counts()
plt.bar(membership_counts.index, membership_counts.values)
plt.title('Distribution of Gym Membership Types')
plt.xlabel('Membership Types')
plt.ylabel('Number of members')
plt.show()

# %% [markdown]
# ## 2. Histogram of time in gym
# Use: plt.hist(gym['avg_time_in_gym'])

# %%
plt.figure(figsize=(8,5))
plt.hist(gym['avg_time_in_gym'], bins=15, color = 'salmon', edgecolor="black")
plt.title('Distribution of Average Time Spent in Gym')
plt.xlabel('Time (Minutes)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## 3. Scatter plot: Age vs visits per week
# Use: plt.scatter(gym['Age'], gym['visit_per_week'])

# %%
plt.figure(figsize=(8,5))
plt.scatter(gym['Age'], gym['visit_per_week'], alpha=0.5, color='purple')
plt.title("Memeber Age vs. Weekly Visit Frequency")
plt.xlabel("Age")
plt.ylabel("Visits per Week")
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# # Task 2: Basic Seaborn (3 Plots)

# %%
# Set a consistent visual style
sns.set_theme(style="whitegrid")

# %% [markdown]
# ## 1. Box plot: Gender vs Age
# Use: sns.boxplot(data=gym, x='gender', y='Age')

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=gym, x= 'gender', y = 'Age', palette='Set2')
plt.title('Age Distribution by Gender')

# %% [markdown]
# ## 2. Count plot: Days per week
# Use: sns.countplot(data=gym, x='days_per_week')

# %%
plt.figure(figsize=(35,8))
sns.countplot(data=gym, x = 'days_per_week',color='lightblue', edgecolor='black', palette='viridis')
plt.title("Frequency of Gym Visits per Week")
plt.xlabel('Days Per Week')
plt.ylabel('No. of Members')
plt.xticks(rotation=45, ha='right', fontsize = 8)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Bar plot: Average visits by membership type
# Use: sns.barplot(data=gym, x='abonoment_type', y='visit_per_week')

# %%
plt.figure(figsize=(8,6))
sns.barplot(data=gym, x = 'abonoment_type', y = 'visit_per_week', palette='magma')
plt.title('Average Weekly Visits by Membership Type')
# Out:
# Text(0.5, 1.0, 'Average Weekly Visits by Membership Type')
